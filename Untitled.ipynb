# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
A_1Fn1 = pd.read_csv('/Users/JohnHood/Desktop/things_from_desktop/A_1Fn1.csv', skiprows=1)

# %%
print(A_1Fn1)
# Out:
#          freq[Hz]  re:Trc1_S12  im:Trc1_S12  re:Trc2_S21  im:Trc2_S21  \
# 0    7.500000e+10    -0.098466    -0.096810     0.093342     0.042177
# 1    7.517500e+10    -0.038093     0.125082     0.012976    -0.098093
# 2    7.535000e+10     0.112403    -0.033627    -0.087664     0.012949
# 3    7.552500e+10    -0.096802    -0.046060     0.013716     0.079431
# 4    7.570000e+10     0.027169     0.095485     0.073592    -0.020691
# 5    7.587500e+10     0.042552    -0.084350    -0.016098    -0.071354
# 6    7.605000e+10    -0.074973     0.052188    -0.072359    -0.009190
# 7    7.622500e+10     0.087002     0.011626    -0.016710     0.071351
# 8    7.640000e+10    -0.039830    -0.082158     0.076503     0.015363
# 9    7.657500e+10    -0.024937     0.093959     0.026205    -0.075197
# 10   7.675000e+10     0.078613    -0.061093    -0.065955    -0.048298
# 11   7.692500e+10    -0.102152     0.003405    -0.067945     0.050006
# ...

# %%
print(A_1Fn1(freq[Hz]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-abf9c1fb0ac6> in <module>()
# ----> 1 print(A_1Fn1(freq[Hz]))
#
# NameError: name 'freq' is not defined
